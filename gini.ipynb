# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = "/content/drive/MyDrive/dataset.xlsx"
Orginal_data = pd.read_excel(file_path)

# %%
Orginal_data
# Out:
#           area  subarea   country   c3  interpolated       id  \
# 0        World    World     World  NaN           NaN      NaN
# 1        World    World     World  NaN           NaN      NaN
# 2        World    World     World  NaN           NaN      NaN
# 3        World    World     World  NaN           NaN      NaN
# 4        World    World     World  NaN           NaN      NaN
# ...        ...      ...       ...  ...           ...      ...
# 16041  Country  Country  Zimbabwe  ZWE  Interpolated      NaN
# 16042  Country  Country  Zimbabwe  ZWE            No  22757.0
# 16043  Country  Country  Zimbabwe  ZWE  Extrapolated      NaN
# 16044  Country  Country  Zimbabwe  ZWE  Extrapolated      NaN
# 16045  Country  Country  Zimbabwe  ZWE  Extrapolated      NaN
#
#                 region_wb          incomegroup  year    population  ...  \
# 0             All regions    All income groups  1950  2.536165e+09  ...
# 1             All regions    All income groups  1951  2.583738e+09  ...
# 2             All regions    All income groups  1952  2.630538e+09  ...
# 3             All regions    All income groups  1953  2.677255e+09  ...
# 4             All regions    All income groups  1954  2.724464e+09  ...
# ...                   ...                  ...   ...           ...  ...
# 16041  Sub-Saharan Africa  Lower middle income  2016  1.403034e+07  ...
# 16042  Sub-Saharan Africa  Lower middle income  2017  1.423660e+07  ...
# 16043  Sub-Saharan Africa  Lower middle income  2018  1.443881e+07  ...
# 16044  Sub-Saharan Africa  Lower middle income  2019  1.464547e+07  ...
# 16045  Sub-Saharan Africa  Lower middle income  2020  1.486293e+07  ...
#
#             y91       y92       y93       y94       y95       y96       y97  \
# 0      11017.54  11752.50  12696.34  13839.34  15213.67  16877.18  19097.49
# 1      11508.75  12303.24  13290.44  14402.79  15867.73  17678.40  19960.43
# 2      11746.71  12540.02  13526.04  14693.84  16167.71  18100.79  20360.68
# 3      12191.45  13068.38  14136.01  15319.54  16848.95  18850.39  21294.91
# 4      12402.17  13248.59  14272.51  15528.65  17072.59  19036.75  21326.53
# ...         ...       ...       ...       ...       ...       ...       ...
# 16041   7924.51   8513.33   9212.55  10163.24  11377.68  13395.61  15781.55
# 16042   8201.87   8809.41   9530.87  10518.14  11771.20  13859.64  16327.79
# 16043   8477.14   9105.07   9850.75  10871.14  12166.26  14324.79  16875.78
# 16044   7844.01   8425.05   9115.03  10059.22  11257.61  13254.93  15615.39
# 16045   7246.27   7783.03   8420.43   9292.67  10399.73  12244.85  14425.44
#
#             y98       y99      y100
# 0      22516.21  28512.81  49393.06
# 1      23218.60  29265.17  50621.23
# 2      23771.20  29847.78  52382.93
# 3      24921.69  31285.61  51742.96
# 4      24983.19  31629.85  53416.11
# ...         ...       ...       ...
# 16041  19204.06  25331.45  49184.71
# 16042  19859.15  26200.41  50881.96
# 16043  20525.66  27079.74  52589.64
# 16044  18992.67  25057.26  48661.92
# 16045  17545.36  23147.80  44953.69
#
# [16046 rows x 252 columns]

# %%
data=Orginal_data[['area', 'subarea', 'country', 'interpolated', 'region_wb', 'year', 'population', 'gdp', 'gini', 'palma', 'p1', 'p2', 'p3', 'p4']]

# %%
data
# Out:
#           area  subarea   country  interpolated           region_wb  year  \
# 0        World    World     World           NaN         All regions  1950
# 1        World    World     World           NaN         All regions  1951
# 2        World    World     World           NaN         All regions  1952
# 3        World    World     World           NaN         All regions  1953
# 4        World    World     World           NaN         All regions  1954
# ...        ...      ...       ...           ...                 ...   ...
# 16041  Country  Country  Zimbabwe  Interpolated  Sub-Saharan Africa  2016
# 16042  Country  Country  Zimbabwe            No  Sub-Saharan Africa  2017
# 16043  Country  Country  Zimbabwe  Extrapolated  Sub-Saharan Africa  2018
# 16044  Country  Country  Zimbabwe  Extrapolated  Sub-Saharan Africa  2019
# 16045  Country  Country  Zimbabwe  Extrapolated  Sub-Saharan Africa  2020
#
#          population      gdp    gini   palma        p1        p2        p3  \
# 0      2.536165e+09  4031.34  68.199  15.721  0.001980  0.006238  0.008008
# 1      2.583738e+09  4189.22  68.047  15.188  0.002029  0.006475  0.009445
# 2      2.630538e+09  4296.13  67.893  14.725  0.003803  0.006359  0.010253
# 3      2.677255e+09  4443.39  67.720  14.415  0.004212  0.007950  0.010680
# 4      2.724464e+09  4511.39  67.907  15.098  0.003204  0.006370  0.013576
# ...             ...      ...     ...     ...       ...       ...       ...
# 16041  1.403034e+07  3678.22  57.534   5.036  0.068368  0.078373  0.080041
# 16042  1.423660e+07  3795.64  57.668   5.064  0.070028  0.080032  0.080032
# 16043  1.443881e+07  3923.03  57.668   5.064  0.070028  0.080032  0.080032
# 16044  1.464547e+07  3630.03  57.668   5.064  0.070028  0.080032  0.080032
# 16045  1.486293e+07  3353.41  57.668   5.064  0.070028  0.080032  0.080032
#
#              p4
# 0      0.012780
# 1      0.014322
# 2      0.016368
# 3      0.019089
# 4      0.015326
# ...         ...
# 16041  0.090047
# 16042  0.090036
# 16043  0.090036
# 16044  0.090036
# 16045  0.090036
#
# [16046 rows x 14 columns]

# %%
data.isnull().sum()
# Out:
# area               0
# subarea            0
# country            0
# interpolated    1207
# region_wb        355
# year               0
# population        71
# gdp               71
# gini              71
# palma             40
# p1               317
# p2               284
# p3               284
# p4               284
# dtype: int64

# %%
sns.boxplot(data.population)
# Out:
# <Axes: >

# %%
 data.population.median()
# Out:
# 4903206.0

# %%
data.population.fillna(data.population.median(),inplace=True)
# Out:
# <ipython-input-12-40a0b8771051>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.population.fillna(data.population.median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# area               0
# subarea            0
# country            0
# interpolated    1207
# region_wb        355
# year               0
# population         0
# gdp               71
# gini              71
# palma             40
# p1               317
# p2               284
# p3               284
# p4               284
# dtype: int64

# %%
sns.boxplot(data.gdp)
# Out:
# <Axes: >

# %%
data.gdp.fillna(data.gdp.median(),inplace=True)
# Out:
# <ipython-input-15-2f43a0872241>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.gdp.fillna(data.gdp.median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# area               0
# subarea            0
# country            0
# interpolated    1207
# region_wb        355
# year               0
# population         0
# gdp                0
# gini              71
# palma             40
# p1               317
# p2               284
# p3               284
# p4               284
# dtype: int64

# %%
sns.boxplot(data.gini)
# Out:
# <Axes: >

# %%
data.gini.fillna(data.gini.median(),inplace=True)
# Out:
# <ipython-input-18-0632f8064e50>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.gini.fillna(data.gini.median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# area               0
# subarea            0
# country            0
# interpolated    1207
# region_wb        355
# year               0
# population         0
# gdp                0
# gini               0
# palma             40
# p1               317
# p2               284
# p3               284
# p4               284
# dtype: int64

# %%
sns.boxplot(data.palma)
# Out:
# <Axes: >

# %%
data.palma.fillna(data.palma.median(),inplace=True)
# Out:
# <ipython-input-21-121e18ab09ad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.palma.fillna(data.palma.median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# area               0
# subarea            0
# country            0
# interpolated    1207
# region_wb        355
# year               0
# population         0
# gdp                0
# gini               0
# palma              0
# p1               317
# p2               284
# p3               284
# p4               284
# dtype: int64

# %%
sns.boxplot(data.p1)
# Out:
# <Axes: >

# %%
data.p1.fillna(data.p1.median(),inplace=True)
# Out:
# <ipython-input-24-3794e2957662>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.p1.fillna(data.p1.median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# area               0
# subarea            0
# country            0
# interpolated    1207
# region_wb        355
# year               0
# population         0
# gdp                0
# gini               0
# palma              0
# p1                 0
# p2               284
# p3               284
# p4               284
# dtype: int64

# %%
data.isnull().sum()
# Out:
# area               0
# subarea            0
# country            0
# interpolated    1207
# region_wb        355
# year               0
# population         0
# gdp                0
# gini               0
# palma              0
# p1                 0
# p2               284
# p3               284
# p4               284
# dtype: int64

# %%
data.p2.fillna(data.p2.median(),inplace=True)
# Out:
# <ipython-input-27-46f7b8360750>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.p2.fillna(data.p2.median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# area               0
# subarea            0
# country            0
# interpolated    1207
# region_wb        355
# year               0
# population         0
# gdp                0
# gini               0
# palma              0
# p1                 0
# p2                 0
# p3               284
# p4               284
# dtype: int64

# %%
sns.boxplot(data.p3)
# Out:
# <Axes: >

# %%
data.p3.fillna(data.p3.median(),inplace=True)
# Out:
# <ipython-input-30-1b49124c897e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.p3.fillna(data.p3.median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# area               0
# subarea            0
# country            0
# interpolated    1207
# region_wb        355
# year               0
# population         0
# gdp                0
# gini               0
# palma              0
# p1                 0
# p2                 0
# p3                 0
# p4               284
# dtype: int64

# %%
sns.boxplot(data.p4)
# Out:
# <Axes: >

# %%
data.p4.fillna(data.p4.median(),inplace=True)
# Out:
# <ipython-input-33-e3a14792feb8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.p4.fillna(data.p4.median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# area               0
# subarea            0
# country            0
# interpolated    1207
# region_wb        355
# year               0
# population         0
# gdp                0
# gini               0
# palma              0
# p1                 0
# p2                 0
# p3                 0
# p4                 0
# dtype: int64

# %%
data.interpolated.fillna(data.interpolated.mode()[0],inplace=True)
# Out:
# <ipython-input-35-0538838b0628>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.interpolated.fillna(data.interpolated.mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# area              0
# subarea           0
# country           0
# interpolated      0
# region_wb       355
# year              0
# population        0
# gdp               0
# gini              0
# palma             0
# p1                0
# p2                0
# p3                0
# p4                0
# dtype: int64

# %%
data.region_wb.fillna(data.region_wb.mode()[0],inplace=True)
# Out:
# <ipython-input-37-b1854cfeb5b1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.region_wb.fillna(data.region_wb.mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# area            0
# subarea         0
# country         0
# interpolated    0
# region_wb       0
# year            0
# population      0
# gdp             0
# gini            0
# palma           0
# p1              0
# p2              0
# p3              0
# p4              0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
data.area=encoder.fit_transform(data.area)
# Out:
# <ipython-input-41-eb93f851db87>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.area=encoder.fit_transform(data.area)

# %%
data
# Out:
#        area  subarea   country  interpolated           region_wb  year  \
# 0         3    World     World  Extrapolated         All regions  1950
# 1         3    World     World  Extrapolated         All regions  1951
# 2         3    World     World  Extrapolated         All regions  1952
# 3         3    World     World  Extrapolated         All regions  1953
# 4         3    World     World  Extrapolated         All regions  1954
# ...     ...      ...       ...           ...                 ...   ...
# 16041     0  Country  Zimbabwe  Interpolated  Sub-Saharan Africa  2016
# 16042     0  Country  Zimbabwe            No  Sub-Saharan Africa  2017
# 16043     0  Country  Zimbabwe  Extrapolated  Sub-Saharan Africa  2018
# 16044     0  Country  Zimbabwe  Extrapolated  Sub-Saharan Africa  2019
# 16045     0  Country  Zimbabwe  Extrapolated  Sub-Saharan Africa  2020
#
#          population      gdp    gini   palma        p1        p2        p3  \
# 0      2.536165e+09  4031.34  68.199  15.721  0.001980  0.006238  0.008008
# 1      2.583738e+09  4189.22  68.047  15.188  0.002029  0.006475  0.009445
# 2      2.630538e+09  4296.13  67.893  14.725  0.003803  0.006359  0.010253
# 3      2.677255e+09  4443.39  67.720  14.415  0.004212  0.007950  0.010680
# 4      2.724464e+09  4511.39  67.907  15.098  0.003204  0.006370  0.013576
# ...             ...      ...     ...     ...       ...       ...       ...
# 16041  1.403034e+07  3678.22  57.534   5.036  0.068368  0.078373  0.080041
# 16042  1.423660e+07  3795.64  57.668   5.064  0.070028  0.080032  0.080032
# 16043  1.443881e+07  3923.03  57.668   5.064  0.070028  0.080032  0.080032
# 16044  1.464547e+07  3630.03  57.668   5.064  0.070028  0.080032  0.080032
# 16045  1.486293e+07  3353.41  57.668   5.064  0.070028  0.080032  0.080032
#
#              p4
# 0      0.012780
# 1      0.014322
# 2      0.016368
# 3      0.019089
# 4      0.015326
# ...         ...
# 16041  0.090047
# 16042  0.090036
# 16043  0.090036
# 16044  0.090036
# 16045  0.090036
#
# [16046 rows x 14 columns]

# %%
data.subarea=encoder.fit_transform(data.subarea)
# Out:
# <ipython-input-43-cb85ba198678>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.subarea=encoder.fit_transform(data.subarea)

# %%
data.country=encoder.fit_transform(data.country)
# Out:
# <ipython-input-44-4f70a4aa7239>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.country=encoder.fit_transform(data.country)

# %%
data.interpolated=encoder.fit_transform(data.interpolated)
# Out:
# <ipython-input-45-13ba54c01e4d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.interpolated=encoder.fit_transform(data.interpolated)

# %%
data.region_wb=encoder.fit_transform(data.region_wb)
# Out:
# <ipython-input-46-4b61ca1cb065>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.region_wb=encoder.fit_transform(data.region_wb)

# %%
data
# Out:
#        area  subarea  country  interpolated  region_wb  year    population  \
# 0         3       13      218             0          0  1950  2.536165e+09
# 1         3       13      218             0          0  1951  2.583738e+09
# 2         3       13      218             0          0  1952  2.630538e+09
# 3         3       13      218             0          0  1953  2.677255e+09
# 4         3       13      218             0          0  1954  2.724464e+09
# ...     ...      ...      ...           ...        ...   ...           ...
# 16041     0        0      221             2          7  2016  1.403034e+07
# 16042     0        0      221             4          7  2017  1.423660e+07
# 16043     0        0      221             0          7  2018  1.443881e+07
# 16044     0        0      221             0          7  2019  1.464547e+07
# 16045     0        0      221             0          7  2020  1.486293e+07
#
#            gdp    gini   palma        p1        p2        p3        p4
# 0      4031.34  68.199  15.721  0.001980  0.006238  0.008008  0.012780
# 1      4189.22  68.047  15.188  0.002029  0.006475  0.009445  0.014322
# 2      4296.13  67.893  14.725  0.003803  0.006359  0.010253  0.016368
# 3      4443.39  67.720  14.415  0.004212  0.007950  0.010680  0.019089
# 4      4511.39  67.907  15.098  0.003204  0.006370  0.013576  0.015326
# ...        ...     ...     ...       ...       ...       ...       ...
# 16041  3678.22  57.534   5.036  0.068368  0.078373  0.080041  0.090047
# 16042  3795.64  57.668   5.064  0.070028  0.080032  0.080032  0.090036
# 16043  3923.03  57.668   5.064  0.070028  0.080032  0.080032  0.090036
# 16044  3630.03  57.668   5.064  0.070028  0.080032  0.080032  0.090036
# 16045  3353.41  57.668   5.064  0.070028  0.080032  0.080032  0.090036
#
# [16046 rows x 14 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
data.population.shape
# Out:
# (16046,)

# %%
x=data.drop("gini",axis=1)
y=data[['gini']]

# %%
clms=x.columns

# %%
scaled=scaler.fit_transform(x)

# %%
X=pd.DataFrame(scaled,columns=clms)

# %%
# Selecting relevant features and target variable
selected_features = ['country','year','area', 'subarea', 'interpolated', 'region_wb', 'population', 'gdp', 'palma', 'p1', 'p2', 'p3', 'p4']  # Include the encoded column

X = data[selected_features]  # Features
y = data['gini']  # Target variable

# %%
X
# Out:
#        country  year  area  subarea  interpolated  region_wb    population  \
# 0          218  1950     3       13             0          0  2.536165e+09
# 1          218  1951     3       13             0          0  2.583738e+09
# 2          218  1952     3       13             0          0  2.630538e+09
# 3          218  1953     3       13             0          0  2.677255e+09
# 4          218  1954     3       13             0          0  2.724464e+09
# ...        ...   ...   ...      ...           ...        ...           ...
# 16041      221  2016     0        0             2          7  1.403034e+07
# 16042      221  2017     0        0             4          7  1.423660e+07
# 16043      221  2018     0        0             0          7  1.443881e+07
# 16044      221  2019     0        0             0          7  1.464547e+07
# 16045      221  2020     0        0             0          7  1.486293e+07
#
#            gdp   palma        p1        p2        p3        p4
# 0      4031.34  15.721  0.001980  0.006238  0.008008  0.012780
# 1      4189.22  15.188  0.002029  0.006475  0.009445  0.014322
# 2      4296.13  14.725  0.003803  0.006359  0.010253  0.016368
# 3      4443.39  14.415  0.004212  0.007950  0.010680  0.019089
# 4      4511.39  15.098  0.003204  0.006370  0.013576  0.015326
# ...        ...     ...       ...       ...       ...       ...
# 16041  3678.22   5.036  0.068368  0.078373  0.080041  0.090047
# 16042  3795.64   5.064  0.070028  0.080032  0.080032  0.090036
# 16043  3923.03   5.064  0.070028  0.080032  0.080032  0.090036
# 16044  3630.03   5.064  0.070028  0.080032  0.080032  0.090036
# 16045  3353.41   5.064  0.070028  0.080032  0.080032  0.090036
#
# [16046 rows x 13 columns]

# %%
y
# Out:
# 0        68.199
# 1        68.047
# 2        67.893
# 3        67.720
# 4        67.907
#           ...
# 16041    57.534
# 16042    57.668
# 16043    57.668
# 16044    57.668
# 16045    57.668
# Name: gini, Length: 16046, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Assuming X and y are your feature matrix and target variable
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# Initialize and train the model (Example: Decision Tree Regressor)
model = DecisionTreeRegressor()

model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate model performance
mse = mean_squared_error(y_test, y_pred)
r_squared = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r_squared}')
# Out:
# Mean Squared Error: 0.4802572591900312
# R-squared: 0.9965894724746566

# %%
# Assuming you have processed values for the encoded country and processed year
processed_country_value =0  # Replace with the processed value for the country
processed_year_value =13  # Replace with the processed value for the year
a=218
b=0
c=0
d=1950
e=2.536165e+09
f=4031.34
g=15.721
h=0.001980
i=0.006238
j=0.006238
k=0.012780

# Ensure the processed values are numerical and compatible with model prediction
try:
    # Use your SVR model to predict the Gini Index using only country and year
    prediction = model.predict([[processed_country_value, processed_year_value,a,b,c,d,e,f,g,h,i,j,k]])
    print(f"Predicted Gini Index for the encoded country : {prediction}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Predicted Gini Index for the encoded country : [77.085]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
data
# Out:
#        area  subarea  country  interpolated  region_wb  year    population  \
# 0         3       13      218             0          0  1950  2.536165e+09
# 1         3       13      218             0          0  1951  2.583738e+09
# 2         3       13      218             0          0  1952  2.630538e+09
# 3         3       13      218             0          0  1953  2.677255e+09
# 4         3       13      218             0          0  1954  2.724464e+09
# ...     ...      ...      ...           ...        ...   ...           ...
# 16041     0        0      221             2          7  2016  1.403034e+07
# 16042     0        0      221             4          7  2017  1.423660e+07
# 16043     0        0      221             0          7  2018  1.443881e+07
# 16044     0        0      221             0          7  2019  1.464547e+07
# 16045     0        0      221             0          7  2020  1.486293e+07
#
#            gdp    gini   palma        p1        p2        p3        p4
# 0      4031.34  68.199  15.721  0.001980  0.006238  0.008008  0.012780
# 1      4189.22  68.047  15.188  0.002029  0.006475  0.009445  0.014322
# 2      4296.13  67.893  14.725  0.003803  0.006359  0.010253  0.016368
# 3      4443.39  67.720  14.415  0.004212  0.007950  0.010680  0.019089
# 4      4511.39  67.907  15.098  0.003204  0.006370  0.013576  0.015326
# ...        ...     ...     ...       ...       ...       ...       ...
# 16041  3678.22  57.534   5.036  0.068368  0.078373  0.080041  0.090047
# 16042  3795.64  57.668   5.064  0.070028  0.080032  0.080032  0.090036
# 16043  3923.03  57.668   5.064  0.070028  0.080032  0.080032  0.090036
# 16044  3630.03  57.668   5.064  0.070028  0.080032  0.080032  0.090036
# 16045  3353.41  57.668   5.064  0.070028  0.080032  0.080032  0.090036
#
# [16046 rows x 14 columns]

# %%
import pickle

# Assuming 'model' is your trained scikit-learn model
model_filename = 'gini.pkl'
with open(model_filename, 'wb') as file:
    pickle.dump(model, file)
